# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fe3ce822-a467-42f2-a1d8-ed33dbe0522a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe3ce822-a467-42f2-a1d8-ed33dbe0522a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('real_estate_dataset.csv')
df.shape
# Out:
# (500, 12)

# %%
df.head()
# Out:
#    ID  Square_Feet  Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built  \
# 0   1   143.635030             1              3           3        1967
# 1   2   287.678577             1              2           1        1949
# 2   3   232.998485             1              3           2        1923
# 3   4   199.664621             5              2           2        1918
# 4   5    89.004660             4              3           3        1999
#
#    Has_Garden  Has_Pool  Garage_Size  Location_Score  Distance_to_Center  \
# 0           1         1           48        8.297631            5.935734
# 1           0         1           37        6.061466           10.827392
# 2           1         0           14        2.911442            6.904599
# 3           0         0           17        2.070949            8.284019
# 4           1         0           34        1.523278           14.648277
#
#            Price
# 0  602134.816747
# 1  591425.135386
# 2  464478.696880
# 3  583105.655996
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  500 non-null    int64
#  1   Square_Feet         500 non-null    float64
#  2   Num_Bedrooms        500 non-null    int64
#  3   Num_Bathrooms       500 non-null    int64
#  4   Num_Floors          500 non-null    int64
#  5   Year_Built          500 non-null    int64
#  6   Has_Garden          500 non-null    int64
#  7   Has_Pool            500 non-null    int64
#  8   Garage_Size         500 non-null    int64
#  9   Location_Score      500 non-null    float64
#  10  Distance_to_Center  500 non-null    float64
#  11  Price               500 non-null    float64
# dtypes: float64(4), int64(8)
# memory usage: 47.0 KB

# %%
df.describe()
# Out:
#                ID  Square_Feet  Num_Bedrooms  Num_Bathrooms  Num_Floors  \
# count  500.000000   500.000000    500.000000     500.000000  500.000000
# mean   250.500000   174.640428      2.958000       1.976000    1.964000
# std    144.481833    74.672102      1.440968       0.820225    0.802491
# min      1.000000    51.265396      1.000000       1.000000    1.000000
# 25%    125.750000   110.319923      2.000000       1.000000    1.000000
# 50%    250.500000   178.290937      3.000000       2.000000    2.000000
# 75%    375.250000   239.031220      4.000000       3.000000    3.000000
# max    500.000000   298.241199      5.000000       3.000000    3.000000
#
#         Year_Built  Has_Garden    Has_Pool  Garage_Size  Location_Score  \
# count   500.000000  500.000000  500.000000   500.000000      500.000000
# mean   1957.604000    0.536000    0.492000    30.174000        5.164410
# std      35.491781    0.499202    0.500437    11.582575        2.853489
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Square_Feet', 'Num_Bedrooms', 'Num_Bathrooms', 'Num_Floors',
#        'Year_Built', 'Has_Garden', 'Has_Pool', 'Garage_Size', 'Location_Score',
#        'Distance_to_Center', 'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                      int64
# Square_Feet           float64
# Num_Bedrooms            int64
# Num_Bathrooms           int64
# Num_Floors              int64
# Year_Built              int64
# Has_Garden              int64
# Has_Pool                int64
# Garage_Size             int64
# Location_Score        float64
# Distance_to_Center    float64
# Price                 float64
# dtype: object

# %%
df.rename(columns={'Garage_Size':'Garage_Size_sq_meter'})
# Out:
#       ID  Square_Feet  Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built  \
# 0      1   143.635030             1              3           3        1967
# 1      2   287.678577             1              2           1        1949
# 2      3   232.998485             1              3           2        1923
# 3      4   199.664621             5              2           2        1918
# 4      5    89.004660             4              3           3        1999
# ..   ...          ...           ...            ...         ...         ...
# 495  496   138.338057             2              2           2        1967
# 496  497   195.914028             2              3           1        1977
# 497  498    69.433659             1              1           2        2004
# 498  499   293.598702             5              1           3        1940
# 499  500   296.552686             4              3           1        1988
#
#      Has_Garden  Has_Pool  Garage_Size_sq_meter  Location_Score  \
# ...

# %%
df.drop(['Distance_to_Center'], axis=1)
# Out:
#       ID  Square_Feet  Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built  \
# 0      1   143.635030             1              3           3        1967
# 1      2   287.678577             1              2           1        1949
# 2      3   232.998485             1              3           2        1923
# 3      4   199.664621             5              2           2        1918
# 4      5    89.004660             4              3           3        1999
# ..   ...          ...           ...            ...         ...         ...
# 495  496   138.338057             2              2           2        1967
# 496  497   195.914028             2              3           1        1977
# 497  498    69.433659             1              1           2        2004
# 498  499   293.598702             5              1           3        1940
# 499  500   296.552686             4              3           1        1988
#
# ...

# %%
df.isna().sum()
# Out:
# ID                    0
# Square_Feet           0
# Num_Bedrooms          0
# Num_Bathrooms         0
# Num_Floors            0
# Year_Built            0
# Has_Garden            0
# Has_Pool              0
# Garage_Size           0
# Location_Score        0
# Distance_to_Center    0
# Price                 0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df['ID'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: ID, Length: 500, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Square_Feet, Num_Bedrooms, Num_Bathrooms, Num_Floors, Year_Built, Has_Garden, Has_Pool, Garage_Size, Location_Score, Distance_to_Center, Price]
# Index: []

# %%
#Extracting duplicates of a particular column
df.loc[df['Num_Floors'].duplicated()].head()
# Out:
#    ID  Square_Feet  Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built  \
# 3   4   199.664621             5              2           2        1918
# 4   5    89.004660             4              3           3        1999
# 5   6    88.998630             5              3           2        1959
# 6   7    64.520903             4              3           1        1938
# 7   8   266.544036             5              1           3        1973
#
#    Has_Garden  Has_Pool  Garage_Size  Location_Score  Distance_to_Center  \
# 3           0         0           17        2.070949            8.284019
# 4           1         0           34        1.523278           14.648277
# 5           1         1           36        8.994552           17.633250
# 6           0         1           32        7.101354            2.429908
# 7           1         1           39        9.373784           12.692785
#
#            Price
# 3  583105.655996
# 4  619879.142523
# 5  670386.804433
# 6  523827.125601
# ...

# %%
#Extracting values for a particular row
df.query('ID==1')
# Out:
#    ID  Square_Feet  Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built  \
# 0   1    143.63503             1              3           3        1967
#
#    Has_Garden  Has_Pool  Garage_Size  Location_Score  Distance_to_Center  \
# 0           1         1           48        8.297631            5.935734
#
#            Price
# 0  602134.816747

# %%
#Extracting duplicate values as per a particular compbination of columns
df.duplicated(subset=['Num_Bedrooms','Num_Bathrooms','Num_Floors','Year_Built'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
#Total number of duplicated for the particular combination
df.duplicated(subset=['Num_Bedrooms','Num_Bathrooms','Num_Floors','Year_Built']).sum()
# Out:
# 17

# %%
#To get the inverse of duplicate
~df.duplicated(subset=['Num_Bedrooms','Num_Bathrooms','Num_Floors','Year_Built'])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Length: 500, dtype: bool

# %%
#Extracting the non-duplicate values
df.loc[~df.duplicated(subset=['Num_Bedrooms','Num_Bathrooms','Num_Floors','Year_Built'])]
# Out:
#       ID  Square_Feet  Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built  \
# 0      1   143.635030             1              3           3        1967
# 1      2   287.678577             1              2           1        1949
# 2      3   232.998485             1              3           2        1923
# 3      4   199.664621             5              2           2        1918
# 4      5    89.004660             4              3           3        1999
# ..   ...          ...           ...            ...         ...         ...
# 495  496   138.338057             2              2           2        1967
# 496  497   195.914028             2              3           1        1977
# 497  498    69.433659             1              1           2        2004
# 498  499   293.598702             5              1           3        1940
# 499  500   296.552686             4              3           1        1988
#
# ...

# %%
df['Year_Built'].value_counts()
# Out:
# Year_Built
# 1959    12
# 1920    12
# 1901    10
# 1935     9
# 1907     9
#         ..
# 1952     1
# 1939     1
# 1936     1
# 1955     1
# 1993     1
# Name: count, Length: 121, dtype: int64

# %%
ax=df['Year_Built'].value_counts().head(10).plot(kind='bar', title='Number_of_houses_built_by_Year_in_Descending_Order')
ax.set_xlabel('Year_Built')
ax.set_ylabel('Number_of_houses_built')
# Out:
# Text(0, 0.5, 'Number_of_houses_built')

# %%
df[['Year_Built','Price']].plot(kind='scatter',x='Year_Built', y='Price', title='Year_Built_vs_Price')
# Out:
# <Axes: title={'center': 'Year_Built_vs_Price'}, xlabel='Year_Built', ylabel='Price'>

# %%
a=sns.scatterplot(x='Price',y='Location_Score', hue='Year_Built', data=df)

# %%
sns.pairplot(df, hue='Year_Built',x_vars=['Num_Bedrooms','Num_Bathrooms','Num_Floors','Year_Built'],y_vars='Price')

# %%
sns.pairplot(df, vars=['Num_Bedrooms','Num_Bathrooms','Num_Floors','Year_Built','Price'], hue='Price')

# %%
dfcorr=df[['Num_Bedrooms','Num_Bathrooms','Num_Floors','Year_Built','Price']].corr()
dfcorr
# Out:
#                Num_Bedrooms  Num_Bathrooms  Num_Floors  Year_Built     Price
# Num_Bedrooms       1.000000      -0.056808    0.009088    0.031806  0.563973
# Num_Bathrooms     -0.056808       1.000000   -0.040895   -0.013407  0.156689
# Num_Floors         0.009088      -0.040895    1.000000    0.046922  0.177435
# Year_Built         0.031806      -0.013407    0.046922    1.000000  0.418293
# Price              0.563973       0.156689    0.177435    0.418293  1.000000

# %%
#Data labels won't be present without anot
sns.heatmap(dfcorr, annot=True)
# Out:
# <Axes: >
